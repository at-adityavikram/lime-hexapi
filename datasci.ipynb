# %%
pwd
# Out:
# 'C:\\Users\\Aditya\\Documents\\JupyterNb'

# %%
import pandas as pd

# %%
df=pd.read_csv("data.csv")

# %%
df.head()
# Out:
#              street        city    zip state  beds  baths  sq__ft  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#           type                     sale_date  price   latitude   longitude
# 0  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146
# 4  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470 -121.435768

# %%
df.head(10)
# Out:
#                             street            city    zip state  beds  baths  \
# 0                     3526 HIGH ST      SACRAMENTO  95838    CA     2      1
# 1                      51 OMAHA CT      SACRAMENTO  95823    CA     3      1
# 2                   2796 BRANCH ST      SACRAMENTO  95815    CA     2      1
# 3                 2805 JANETTE WAY      SACRAMENTO  95815    CA     2      1
# 4                  6001 MCMAHON DR      SACRAMENTO  95824    CA     2      1
# 5               5828 PEPPERMILL CT      SACRAMENTO  95841    CA     3      1
# 6              6048 OGDEN NASH WAY      SACRAMENTO  95842    CA     3      2
# 7                    2561 19TH AVE      SACRAMENTO  95820    CA     3      1
# 8  11150 TRINITY RIVER DR Unit 114  RANCHO CORDOVA  95670    CA     2      2
# 9                     7325 10TH ST       RIO LINDA  95673    CA     3      2
#
#    sq__ft         type                     sale_date  price   latitude  \
# ...

# %%
df['price']
# Out:
# 0       59222
# 1       68212
# 2       68880
# 3       69307
# 4       81900
#         ...
# 980    232425
# 981    234000
# 982    235000
# 983    235301
# 984    235738
# Name: price, Length: 985, dtype: int64

# %%
df['city','price']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Z:\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('city', 'price')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-3752deb44f57> in <module>
# ----> 1 df['city','price']
#
# ...

# %%
df['city'],['price']
# Out:
# (0           SACRAMENTO
#  1           SACRAMENTO
#  2           SACRAMENTO
#  3           SACRAMENTO
#  4           SACRAMENTO
#              ...
#  980         SACRAMENTO
#  981         SACRAMENTO
#  982     CITRUS HEIGHTS
#  983          ELK GROVE
#  984    EL DORADO HILLS
#  Name: city, Length: 985, dtype: object,
#  ['price'])

# %%
df.head()
# Out:
#      name  age  TestScore_1  TestScore_2
# 0   Kunal   42            4           25
# 1   Ankit   52           24           94
# 2   Purva   36           31           57
# 3  Pranav   24            2           62
# 4   Sunil   73            3           70

# %%
df[['city'],['price']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-84264ef0df18> in <module>
# ----> 1 df[['city'],['price']]
#
# Z:\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# Z:\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2644                 )
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#    2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
df[['city','price']]
# Out:
#                 city   price
# 0         SACRAMENTO   59222
# 1         SACRAMENTO   68212
# 2         SACRAMENTO   68880
# 3         SACRAMENTO   69307
# 4         SACRAMENTO   81900
# ..               ...     ...
# 980       SACRAMENTO  232425
# 981       SACRAMENTO  234000
# 982   CITRUS HEIGHTS  235000
# 983        ELK GROVE  235301
# 984  EL DORADO HILLS  235738
#
# [985 rows x 2 columns]

# %%
df.iloc[4:8]
# Out:
#                 street        city    zip state  beds  baths  sq__ft  \
# 4      6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
# 5   5828 PEPPERMILL CT  SACRAMENTO  95841    CA     3      1    1122
# 6  6048 OGDEN NASH WAY  SACRAMENTO  95842    CA     3      2    1104
# 7        2561 19TH AVE  SACRAMENTO  95820    CA     3      1    1177
#
#           type                     sale_date  price   latitude   longitude
# 4  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470 -121.435768
# 5        Condo  Wed May 21 00:00:00 EDT 2008  89921  38.662595 -121.327813
# 6  Residential  Wed May 21 00:00:00 EDT 2008  90895  38.681659 -121.351705
# 7  Residential  Wed May 21 00:00:00 EDT 2008  91002  38.535092 -121.481367

# %%
df.iloc[:,:2]
# Out:
#                   street             city
# 0           3526 HIGH ST       SACRAMENTO
# 1            51 OMAHA CT       SACRAMENTO
# 2         2796 BRANCH ST       SACRAMENTO
# 3       2805 JANETTE WAY       SACRAMENTO
# 4        6001 MCMAHON DR       SACRAMENTO
# ..                   ...              ...
# 980   9169 GARLINGTON CT       SACRAMENTO
# 981      6932 RUSKUT WAY       SACRAMENTO
# 982    7933 DAFFODIL WAY   CITRUS HEIGHTS
# 983     8304 RED FOX WAY        ELK GROVE
# 984  3882 YELLOWSTONE LN  EL DORADO HILLS
#
# [985 rows x 2 columns]

# %%
print("i want to die".replace("die","go to sleep"))
# Out:
# i want to go to sleep

# %%
data = {'name': ['Kunal', 'Ankit', 'Purva', 'Pranav', 'Sunil'], 
        'age': [42, 52, 36, 24, 73], 
        'TestScore_1': [4, 24, 31, 2, 3],
        'TestScore_2': [25, 94, 57, 62, 70]}

# %%
df = pd.DataFrame(data, columns = ['name', 'age', 'TestScore_1', 'TestScore_2'])

# %%
df.head()
# Out:
#      name  age  TestScore_1  TestScore_2
# 0   Kunal   42            4           25
# 1   Ankit   52           24           94
# 2   Purva   36           31           57
# 3  Pranav   24            2           62
# 4   Sunil   73            3           70

# %%
df
# Out:
#      name  age  TestScore_1  TestScore_2
# 0   Kunal   42            4           25
# 1   Ankit   52           24           94
# 2   Purva   36           31           57
# 3  Pranav   24            2           62
# 4   Sunil   73            3           70

# %%
df['TestScore_1'].sum()
# Out:
# 64

# %%
df['TestScore_1'].mean()
# Out:
# 12.8

# %%
df['TestScore_1'].cumsum()
# Out:
# 0     4
# 1    28
# 2    59
# 3    61
# 4    64
# Name: TestScore_1, dtype: int64

# %%
df['TestScore_1'].describe()
# Out:
# count     5.000000
# mean     12.800000
# std      13.663821
# min       2.000000
# 25%       3.000000
# 50%       4.000000
# 75%      24.000000
# max      31.000000
# Name: TestScore_1, dtype: float64

# %%
df.corr()
# Out:
#                   age  TestScore_1  TestScore_2
# age          1.000000    -0.105651     0.328852
# TestScore_1 -0.105651     1.000000     0.378039
# TestScore_2  0.328852     0.378039     1.000000

# %% [markdown]
# # Data Manipulation

# %%
df=pd.read_csv("data.csv")

# %%
import pandas as pd
import numpy as np

# %%
df.head()
# Out:
#              street        city    zip state  beds  baths  sq__ft  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#           type                     sale_date  price   latitude   longitude
# 0  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146
# 4  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470 -121.435768

# %%
pwd
# Out:
# 'C:\\Users\\Aditya\\Documents\\JupyterNb'

# %%
data_BM=pd.read_csv("bigmart_data.csv")

# %%
data_BM.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
bata_BM= data_BM.dropna(how="any")

# %%
data_BM.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# sort by year
sorted_data = data_BM.sort_values(by='Outlet_Establishment_Year')

#Print sorted data
sorted_data[:10]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4338           FDH21          NaN          Low Fat         0.031074
# 3689           FDD53          NaN          Low Fat         0.044008
# 1139           FDH26          NaN          Regular         0.034532
# 1138           FDM21          NaN          Low Fat         0.064052
# 3691           FDY36          NaN          Low Fat         0.016477
# 1136           FDT46          NaN          Low Fat         0.030658
# 7478           DRF37          NaN          Low Fat         0.000000
# 1134           FDJ02          NaN          Regular         0.044064
# 1131           FDL02          NaN          Regular         0.182237
# 1130           FDY52          NaN          Low Fat         0.012866
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 4338       Seafood  157.5604            OUT027                       1985
# ...

# %%
#sort inplace and descending order
data_BM.sort_values(by='Outlet_Establishment_Year', ascending = False, inplace=True)
data_BM[:5]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 5371           FDC11        20.50          Low Fat         0.142370
# 3846           NCY06        15.25          Low Fat         0.061434
# 874            FDS21        19.85          Regular         0.020961
# 6604           FDA11         7.75          Low Fat         0.043415
# 3839           DRI37        15.85          Low Fat         0.108036
#
#           Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 5371  Starchy Foods   90.6172            OUT018                       2009
# 3846      Household  130.9968            OUT018                       2009
# 874     Snack Foods   62.0194            OUT018                       2009
# 6604   Baking Goods   93.1436            OUT018                       2009
# 3839    Soft Drinks   57.3904            OUT018                       2009
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
#read the dataset
data_BM = pd.read_csv('bigmart_data.csv')

#drop the NULL values
data_BM = data_BM.dropna(how="any")

#sort by multiple columns
data_BM.sort_values(by=['Outlet_Establishment_Year', 'Item_Outlet_Sales'], ascending = False)[:5]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 43             FDC02        21.35          Low Fat         0.069103
# 2803           FDU51        20.20          Regular         0.096907
# 641            FDY51        12.50          Low Fat         0.081465
# 2282           NCX30        16.70          Low Fat         0.026729
# 2887           FDR25        17.00          Regular         0.140090
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 43       Canned  259.9278            OUT018                       2009
# 2803       Meat  175.5028            OUT018                       2009
# 641        Meat  220.7798            OUT018                       2009
# 2282  Household  248.4776            OUT018                       2009
# 2887     Canned  265.1884            OUT018                       2009
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
data_BM.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
data_BM.shape
# Out:
# (4650, 12)
